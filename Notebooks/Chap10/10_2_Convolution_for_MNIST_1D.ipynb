# %% [markdown]
# <a href="https://colab.research.google.com/github/SafalThapa17/DeepLearningPREP/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-klhtnh7n
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-klhtnh7n
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=035ce89a393ecf9d492725239a097a0125b8e3f834b66ec9931d5a02ac2f0405
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ostk3cr/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)  # Adjust input size to match the flattened size
)

# %%
print(model)
# Out:
# Sequential(
#   (0): Conv1d(1, 15, kernel_size=(3,), stride=(2,))
#   (1): ReLU()
#   (2): Conv1d(15, 15, kernel_size=(3,), stride=(2,))
#   (3): ReLU()
#   (4): Conv1d(15, 15, kernel_size=(3,), stride=(2,))
#   (5): ReLU()
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=60, out_features=10, bias=True)
# )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.929241, train error 77.93,  val loss 1.927255, percent error 78.60
# Epoch     1, train loss 1.530580, train error 60.90,  val loss 1.558441, percent error 64.60
# Epoch     2, train loss 1.377181, train error 57.33,  val loss 1.411210, percent error 60.30
# Epoch     3, train loss 1.344853, train error 55.75,  val loss 1.372249, percent error 59.40
# Epoch     4, train loss 1.220335, train error 50.10,  val loss 1.239803, percent error 52.40
# Epoch     5, train loss 1.173491, train error 47.67,  val loss 1.194299, percent error 48.80
# Epoch     6, train loss 1.126521, train error 46.45,  val loss 1.162506, percent error 47.60
# Epoch     7, train loss 1.111659, train error 45.33,  val loss 1.138720, percent error 47.50
# Epoch     8, train loss 1.089723, train error 43.60,  val loss 1.140110, percent error 47.00
# Epoch     9, train loss 0.914588, train error 36.83,  val loss 0.962608, percent error 38.10
# Epoch    10, train loss 0.911459, train error 36.15,  val loss 0.961492, percent error 37.40
# Epoch    11, train loss 0.952989, train error 36.22,  val loss 0.998312, percent error 37.40
# Epoch    12, train loss 0.677582, train error 25.95,  val loss 0.729235, percent error 29.10
# Epoch    13, train loss 0.637844, train error 24.97,  val loss 0.702765, percent error 26.40
# Epoch    14, train loss 0.551328, train error 20.60,  val loss 0.646052, percent error 22.70
# Epoch    15, train loss 0.499847, train error 19.28,  val loss 0.599641, percent error 23.10
# Epoch    16, train loss 0.451907, train error 16.50,  val loss 0.525317, percent error 20.10
# Epoch    17, train loss 0.430222, train error 16.78,  val loss 0.523176, percent error 19.80
# Epoch    18, train loss 0.365719, train error 13.62,  val loss 0.460840, percent error 18.10
# Epoch    19, train loss 0.494512, train error 18.10,  val loss 0.564163, percent error 20.10
# Epoch    20, train loss 0.309731, train error 11.38,  val loss 0.433227, percent error 15.30
# Epoch    21, train loss 0.276952, train error 10.28,  val loss 0.403555, percent error 14.30
# Epoch    22, train loss 0.252520, train error 8.85,  val loss 0.393708, percent error 13.10
# Epoch    23, train loss 0.251412, train error 9.07,  val loss 0.398905, percent error 14.40
# Epoch    24, train loss 0.237579, train error 8.25,  val loss 0.417612, percent error 13.80
# Epoch    25, train loss 0.236215, train error 8.78,  val loss 0.388667, percent error 12.80
# Epoch    26, train loss 0.249527, train error 8.70,  val loss 0.400772, percent error 13.00
# Epoch    27, train loss 0.209731, train error 7.62,  val loss 0.391281, percent error 12.40
# Epoch    28, train loss 0.188471, train error 6.55,  val loss 0.358903, percent error 11.40
# Epoch    29, train loss 0.201501, train error 7.00,  val loss 0.380092, percent error 11.90
# Epoch    30, train loss 0.201909, train error 7.40,  val loss 0.409913, percent error 13.10
# Epoch    31, train loss 0.191975, train error 7.00,  val loss 0.408217, percent error 12.80
# Epoch    32, train loss 0.193537, train error 6.72,  val loss 0.407898, percent error 13.30
# Epoch    33, train loss 0.173481, train error 5.95,  val loss 0.367162, percent error 11.30
# Epoch    34, train loss 0.175915, train error 6.38,  val loss 0.391782, percent error 11.40
# Epoch    35, train loss 0.174436, train error 6.18,  val loss 0.382147, percent error 12.00
# Epoch    36, train loss 0.162830, train error 5.43,  val loss 0.377876, percent error 12.10
# Epoch    37, train loss 0.164937, train error 6.15,  val loss 0.408067, percent error 13.30
# Epoch    38, train loss 0.198729, train error 7.53,  val loss 0.416126, percent error 12.80
# Epoch    39, train loss 0.190668, train error 7.32,  val loss 0.456913, percent error 13.70
# Epoch    40, train loss 0.126906, train error 4.22,  val loss 0.357471, percent error 10.20
# Epoch    41, train loss 0.132436, train error 4.50,  val loss 0.383169, percent error 11.50
# Epoch    42, train loss 0.115694, train error 3.65,  val loss 0.372286, percent error 10.70
# Epoch    43, train loss 0.118041, train error 3.72,  val loss 0.365737, percent error 11.30
# Epoch    44, train loss 0.122118, train error 3.90,  val loss 0.385685, percent error 11.00
# Epoch    45, train loss 0.113239, train error 3.72,  val loss 0.382542, percent error 11.10
# Epoch    46, train loss 0.108802, train error 3.15,  val loss 0.379862, percent error 10.40
# Epoch    47, train loss 0.118615, train error 4.12,  val loss 0.409830, percent error 11.90
# Epoch    48, train loss 0.122459, train error 4.50,  val loss 0.399489, percent error 11.60
# Epoch    49, train loss 0.117614, train error 4.07,  val loss 0.407802, percent error 11.20
# Epoch    50, train loss 0.102258, train error 3.25,  val loss 0.377234, percent error 10.50
# Epoch    51, train loss 0.102115, train error 3.35,  val loss 0.394226, percent error 10.70
# Epoch    52, train loss 0.113140, train error 3.85,  val loss 0.413735, percent error 11.10
# Epoch    53, train loss 0.096617, train error 2.70,  val loss 0.395464, percent error 10.10
# Epoch    54, train loss 0.104463, train error 3.38,  val loss 0.400173, percent error 10.70
# Epoch    55, train loss 0.094650, train error 2.62,  val loss 0.409363, percent error 10.70
# Epoch    56, train loss 0.097008, train error 3.18,  val loss 0.408670, percent error 10.90
# Epoch    57, train loss 0.115476, train error 4.22,  val loss 0.431130, percent error 11.10
# Epoch    58, train loss 0.103244, train error 3.55,  val loss 0.441959, percent error 12.10
# Epoch    59, train loss 0.087599, train error 2.60,  val loss 0.399510, percent error 10.30
# Epoch    60, train loss 0.080487, train error 2.25,  val loss 0.413129, percent error 10.40
# Epoch    61, train loss 0.079280, train error 2.05,  val loss 0.408853, percent error 10.40
# Epoch    62, train loss 0.079824, train error 2.40,  val loss 0.422811, percent error 10.60
# Epoch    63, train loss 0.080691, train error 2.28,  val loss 0.407233, percent error 10.40
# Epoch    64, train loss 0.077385, train error 2.15,  val loss 0.412059, percent error 10.40
# Epoch    65, train loss 0.075383, train error 2.12,  val loss 0.417293, percent error 10.40
# Epoch    66, train loss 0.074612, train error 2.00,  val loss 0.415726, percent error 10.30
# Epoch    67, train loss 0.076684, train error 1.80,  val loss 0.415519, percent error 10.90
# Epoch    68, train loss 0.074251, train error 2.00,  val loss 0.428884, percent error 10.20
# Epoch    69, train loss 0.073865, train error 2.07,  val loss 0.422105, percent error 10.20
# Epoch    70, train loss 0.075476, train error 2.15,  val loss 0.422417, percent error 10.90
# Epoch    71, train loss 0.071715, train error 1.88,  val loss 0.419194, percent error 10.10
# Epoch    72, train loss 0.072609, train error 1.88,  val loss 0.423896, percent error 10.80
# Epoch    73, train loss 0.071035, train error 1.97,  val loss 0.416428, percent error 10.20
# Epoch    74, train loss 0.072521, train error 1.95,  val loss 0.420111, percent error 10.30
# Epoch    75, train loss 0.071127, train error 1.93,  val loss 0.432110, percent error 11.00
# Epoch    76, train loss 0.068530, train error 1.75,  val loss 0.438772, percent error 10.70
# Epoch    77, train loss 0.070423, train error 1.93,  val loss 0.434482, percent error 10.60
# Epoch    78, train loss 0.068058, train error 1.72,  val loss 0.434972, percent error 10.60
# Epoch    79, train loss 0.067628, train error 1.85,  val loss 0.425425, percent error 10.30
# Epoch    80, train loss 0.065466, train error 1.55,  val loss 0.430369, percent error 10.60
# Epoch    81, train loss 0.066477, train error 1.85,  val loss 0.448868, percent error 11.10
# Epoch    82, train loss 0.064009, train error 1.60,  val loss 0.433121, percent error 10.60
# Epoch    83, train loss 0.064815, train error 1.80,  val loss 0.446433, percent error 10.80
# Epoch    84, train loss 0.063256, train error 1.68,  val loss 0.441062, percent error 11.10
# Epoch    85, train loss 0.062833, train error 1.60,  val loss 0.439952, percent error 10.70
# Epoch    86, train loss 0.064286, train error 1.50,  val loss 0.433731, percent error 10.50
# Epoch    87, train loss 0.062978, train error 1.50,  val loss 0.439777, percent error 10.90
# Epoch    88, train loss 0.062690, train error 1.55,  val loss 0.441744, percent error 10.60
# Epoch    89, train loss 0.061868, train error 1.60,  val loss 0.443733, percent error 10.70
# Epoch    90, train loss 0.064308, train error 1.80,  val loss 0.451323, percent error 10.60
# Epoch    91, train loss 0.061608, train error 1.62,  val loss 0.444047, percent error 10.50
# Epoch    92, train loss 0.063264, train error 1.65,  val loss 0.437669, percent error 10.60
# Epoch    93, train loss 0.060675, train error 1.50,  val loss 0.445482, percent error 10.60
# Epoch    94, train loss 0.060502, train error 1.53,  val loss 0.449159, percent error 11.00
# Epoch    95, train loss 0.059948, train error 1.53,  val loss 0.449670, percent error 10.80
# Epoch    96, train loss 0.059891, train error 1.50,  val loss 0.448886, percent error 10.60
# Epoch    97, train loss 0.059884, train error 1.60,  val loss 0.455134, percent error 10.80
# Epoch    98, train loss 0.059517, train error 1.60,  val loss 0.453376, percent error 10.60
# Epoch    99, train loss 0.059890, train error 1.50,  val loss 0.459786, percent error 11.00
