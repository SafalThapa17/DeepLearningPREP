# %% [markdown]
# <a href="https://colab.research.google.com/github/SafalThapa17/DeepLearningPREP/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-5motk6gq
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-5motk6gq
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  # TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
        h1 = self.linear1(x).relu()
        h2 = self.linear2(h1).relu()
        h2 = h2 + h1
        h3 = self.linear3(h2).relu()
        h3 = h3 + h2
        return self.linear4(h3)

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.638577, train error 65.22,  val loss 1.708859, percent error 69.60
# Epoch     1, train loss 1.337860, train error 48.70,  val loss 1.445236, percent error 56.30
# Epoch     2, train loss 1.124439, train error 39.92,  val loss 1.281994, percent error 48.40
# Epoch     3, train loss 0.974635, train error 34.35,  val loss 1.195930, percent error 47.60
# Epoch     4, train loss 0.865070, train error 30.85,  val loss 1.139375, percent error 44.30
# Epoch     5, train loss 0.793900, train error 28.50,  val loss 1.151143, percent error 45.10
# Epoch     6, train loss 0.724182, train error 25.10,  val loss 1.111198, percent error 42.60
# Epoch     7, train loss 0.691883, train error 24.40,  val loss 1.149522, percent error 42.70
# Epoch     8, train loss 0.650143, train error 22.88,  val loss 1.149365, percent error 41.00
# Epoch     9, train loss 0.539267, train error 18.25,  val loss 1.133249, percent error 40.90
# Epoch    10, train loss 0.486617, train error 16.30,  val loss 1.170560, percent error 42.00
# Epoch    11, train loss 0.445237, train error 14.55,  val loss 1.213032, percent error 42.30
# Epoch    12, train loss 0.367814, train error 11.95,  val loss 1.207149, percent error 39.20
# Epoch    13, train loss 0.337543, train error 10.40,  val loss 1.208117, percent error 38.90
# Epoch    14, train loss 0.347410, train error 13.47,  val loss 1.335297, percent error 40.40
# Epoch    15, train loss 0.268198, train error 8.00,  val loss 1.318786, percent error 39.40
# Epoch    16, train loss 0.231473, train error 7.50,  val loss 1.317707, percent error 39.40
# Epoch    17, train loss 0.209657, train error 6.55,  val loss 1.416628, percent error 39.10
# Epoch    18, train loss 0.178422, train error 5.12,  val loss 1.463667, percent error 38.80
# Epoch    19, train loss 0.173636, train error 5.03,  val loss 1.498722, percent error 38.00
# Epoch    20, train loss 0.081190, train error 1.10,  val loss 1.464015, percent error 36.30
# Epoch    21, train loss 0.056029, train error 0.25,  val loss 1.421492, percent error 35.00
# Epoch    22, train loss 0.043521, train error 0.07,  val loss 1.452256, percent error 35.80
# Epoch    23, train loss 0.037224, train error 0.00,  val loss 1.494030, percent error 35.30
# Epoch    24, train loss 0.032137, train error 0.00,  val loss 1.521776, percent error 35.50
# Epoch    25, train loss 0.028181, train error 0.00,  val loss 1.549365, percent error 35.30
# Epoch    26, train loss 0.025172, train error 0.00,  val loss 1.575857, percent error 34.70
# Epoch    27, train loss 0.023630, train error 0.00,  val loss 1.600283, percent error 35.80
# Epoch    28, train loss 0.020863, train error 0.00,  val loss 1.612253, percent error 35.30
# Epoch    29, train loss 0.019361, train error 0.00,  val loss 1.640698, percent error 35.10
# Epoch    30, train loss 0.017768, train error 0.00,  val loss 1.668289, percent error 35.40
# Epoch    31, train loss 0.016663, train error 0.00,  val loss 1.675987, percent error 35.40
# Epoch    32, train loss 0.015169, train error 0.00,  val loss 1.692811, percent error 35.60
# Epoch    33, train loss 0.014334, train error 0.00,  val loss 1.717901, percent error 35.80
# Epoch    34, train loss 0.013413, train error 0.00,  val loss 1.735329, percent error 35.50
# Epoch    35, train loss 0.012684, train error 0.00,  val loss 1.742166, percent error 35.60
# Epoch    36, train loss 0.011956, train error 0.00,  val loss 1.763257, percent error 35.80
# Epoch    37, train loss 0.011214, train error 0.00,  val loss 1.778049, percent error 35.70
# Epoch    38, train loss 0.010645, train error 0.00,  val loss 1.795378, percent error 35.50
# Epoch    39, train loss 0.010269, train error 0.00,  val loss 1.801774, percent error 35.80
# Epoch    40, train loss 0.009781, train error 0.00,  val loss 1.811985, percent error 35.80
# Epoch    41, train loss 0.009541, train error 0.00,  val loss 1.817411, percent error 35.90
# Epoch    42, train loss 0.009316, train error 0.00,  val loss 1.822399, percent error 35.60
# Epoch    43, train loss 0.009130, train error 0.00,  val loss 1.831089, percent error 35.90
# Epoch    44, train loss 0.008932, train error 0.00,  val loss 1.838671, percent error 36.00
# Epoch    45, train loss 0.008752, train error 0.00,  val loss 1.842189, percent error 35.70
# Epoch    46, train loss 0.008558, train error 0.00,  val loss 1.849212, percent error 35.80
# Epoch    47, train loss 0.008398, train error 0.00,  val loss 1.853092, percent error 36.00
# Epoch    48, train loss 0.008222, train error 0.00,  val loss 1.860067, percent error 35.90
# Epoch    49, train loss 0.008035, train error 0.00,  val loss 1.863612, percent error 36.00
# Epoch    50, train loss 0.007880, train error 0.00,  val loss 1.871208, percent error 36.00
# Epoch    51, train loss 0.007732, train error 0.00,  val loss 1.875688, percent error 35.80
# Epoch    52, train loss 0.007588, train error 0.00,  val loss 1.883569, percent error 36.00
# Epoch    53, train loss 0.007458, train error 0.00,  val loss 1.885535, percent error 36.10
# Epoch    54, train loss 0.007307, train error 0.00,  val loss 1.891021, percent error 36.00
# Epoch    55, train loss 0.007174, train error 0.00,  val loss 1.898038, percent error 36.10
# Epoch    56, train loss 0.007046, train error 0.00,  val loss 1.901619, percent error 36.30
# Epoch    57, train loss 0.006921, train error 0.00,  val loss 1.907233, percent error 36.10
# Epoch    58, train loss 0.006807, train error 0.00,  val loss 1.913421, percent error 36.10
# Epoch    59, train loss 0.006688, train error 0.00,  val loss 1.916355, percent error 36.10
# Epoch    60, train loss 0.006619, train error 0.00,  val loss 1.919199, percent error 36.30
# Epoch    61, train loss 0.006560, train error 0.00,  val loss 1.922334, percent error 36.10
# Epoch    62, train loss 0.006505, train error 0.00,  val loss 1.923555, percent error 36.20
# Epoch    63, train loss 0.006453, train error 0.00,  val loss 1.926908, percent error 36.20
# Epoch    64, train loss 0.006399, train error 0.00,  val loss 1.929190, percent error 36.20
# Epoch    65, train loss 0.006347, train error 0.00,  val loss 1.931816, percent error 36.20
# Epoch    66, train loss 0.006298, train error 0.00,  val loss 1.933727, percent error 36.30
# Epoch    67, train loss 0.006247, train error 0.00,  val loss 1.935752, percent error 36.20
# Epoch    68, train loss 0.006196, train error 0.00,  val loss 1.938308, percent error 36.30
# Epoch    69, train loss 0.006148, train error 0.00,  val loss 1.940812, percent error 36.20
# Epoch    70, train loss 0.006098, train error 0.00,  val loss 1.942518, percent error 36.40
# Epoch    71, train loss 0.006053, train error 0.00,  val loss 1.944897, percent error 36.30
# Epoch    72, train loss 0.006005, train error 0.00,  val loss 1.947934, percent error 36.30
# Epoch    73, train loss 0.005960, train error 0.00,  val loss 1.949725, percent error 36.30
# Epoch    74, train loss 0.005910, train error 0.00,  val loss 1.951706, percent error 36.30
# Epoch    75, train loss 0.005866, train error 0.00,  val loss 1.953736, percent error 36.40
# Epoch    76, train loss 0.005822, train error 0.00,  val loss 1.957185, percent error 36.30
# Epoch    77, train loss 0.005777, train error 0.00,  val loss 1.959383, percent error 36.30
# Epoch    78, train loss 0.005734, train error 0.00,  val loss 1.960224, percent error 36.30
# Epoch    79, train loss 0.005695, train error 0.00,  val loss 1.962139, percent error 36.30
# Epoch    80, train loss 0.005670, train error 0.00,  val loss 1.963362, percent error 36.40
# Epoch    81, train loss 0.005648, train error 0.00,  val loss 1.965145, percent error 36.40
# Epoch    82, train loss 0.005627, train error 0.00,  val loss 1.965495, percent error 36.40
# Epoch    83, train loss 0.005606, train error 0.00,  val loss 1.967044, percent error 36.40
# Epoch    84, train loss 0.005585, train error 0.00,  val loss 1.968253, percent error 36.40
# Epoch    85, train loss 0.005566, train error 0.00,  val loss 1.968842, percent error 36.30
# Epoch    86, train loss 0.005546, train error 0.00,  val loss 1.970036, percent error 36.40
# Epoch    87, train loss 0.005525, train error 0.00,  val loss 1.971034, percent error 36.30
# Epoch    88, train loss 0.005506, train error 0.00,  val loss 1.972283, percent error 36.40
# Epoch    89, train loss 0.005485, train error 0.00,  val loss 1.973351, percent error 36.30
# Epoch    90, train loss 0.005465, train error 0.00,  val loss 1.974579, percent error 36.40
# Epoch    91, train loss 0.005446, train error 0.00,  val loss 1.974918, percent error 36.30
# Epoch    92, train loss 0.005427, train error 0.00,  val loss 1.976135, percent error 36.40
# Epoch    93, train loss 0.005408, train error 0.00,  val loss 1.977329, percent error 36.30
# Epoch    94, train loss 0.005389, train error 0.00,  val loss 1.978297, percent error 36.50
# Epoch    95, train loss 0.005369, train error 0.00,  val loss 1.979464, percent error 36.40
# Epoch    96, train loss 0.005350, train error 0.00,  val loss 1.980190, percent error 36.40
# Epoch    97, train loss 0.005331, train error 0.00,  val loss 1.981200, percent error 36.40
# Epoch    98, train loss 0.005312, train error 0.00,  val loss 1.982075, percent error 36.40
# Epoch    99, train loss 0.005294, train error 0.00,  val loss 1.983176, percent error 36.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
